# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
depth_wqucp2=pd.read_csv("alter_randomPairesSeed1.csv")
size_wqucp2=pd.read_csv("randomPairesSeed1.csv")
size_wqucp1=pd.read_csv("weight_randomPairesSeed1.csv")

# %%
plt.figure(figsize=(15,10))
plt.plot(depth_wqucp2['N'],depth_wqucp2['Time'],'o-',label="depth weighted quick-union with 2 loops compression")
plt.plot(size_wqucp2['N'],size_wqucp2['Time'],'o-',label="size weighted quick-union with 2 loops compression")
plt.plot(size_wqucp1['N'],size_wqucp1['Time'],'o-',label="size weighted quick-union with 1 loops compression")
plt.xlabel("N nodes")
plt.ylabel("Time (milionSecond)")
plt.legend()
